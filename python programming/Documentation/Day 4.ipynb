# %% [markdown]
# FUNCTION
#
# A function in Python is a reusable block of code that performs a specific task.
# Functions help in code reuse, readability, and easy maintenance.
#
# Types of functions:
#  - Built-in functions
#  - user defined functions
#  - lambda function
#
#  Syntax:
#
#  def function_name(parameters):
#     """Docstring: explains what the function does"""
#     statements
#     return value

# %%
def add(a, b):
    """Returns sum of two numbers"""
    return a + b

result = add(10, 20)
print(result)
# Out:
# 30

# %%
'''Built in function example'''

print("Hello Sakshi")
# Out:
# Hello Sakshi

# %%
'''
A lambda function is a small anonymous function used for short operations.

Syntax:
lambda arguments : expression

'''

square = lambda x: x * x
print(square(5))
# Out:
# 25

# %% [markdown]
# Examples of built-in functions

# %%
# to fint the length
len("Python")
# Out:
# 6

# %%
x = 10
print(type(x))  #this is will print type we can skip print
# Out:
# <class 'int'>

# %%
# this will print maximum and minimum number from the list
numbers = [10,20,30,40,50]
print(max(numbers))
print(min(numbers))
# Out:
# 50
# 10

# %%
marks = [20,30]
print(sum(marks))
# Out:
# 50

# %%
print(len("Hello"))
print(type(5.5))
print(int("25") + 5)
# Out:
# 5
# <class 'float'>
# 30

# %% [markdown]
# USER-DEFINED FUNCTIONS
#
# A user defined function is a function created by the user to perform a specific task.
# It helps in code reusability, readability, and modular programming.

# %%
# programs of user-defined functions

def add(a,b):
    return a + b
    return result

print(add(10,20))
# Out:
# 30

# %%
# Function without parameter
def greet():
    print("hello Sakshi")

greet()
# Out:
# hello Sakshi

# %%
# Function with parameters

def square(n):
    return n*n

print(square(5))
# Out:
# 25

# %%
# Function with return value

def area_of_circle(r):
    return 3.14 * r * r

print(area_of_circle(7))
# Out:
# 153.86

# %%
# Function without return value

def message():
    print("Python")

message()
# Out:
# Python

# %%
# Function call flow

def multiply(a , b):
    return a * b

result = multiply(4, 5)
print(result)
# Out:
# 20

# %%
def check_year(year):
    if year % 4 == 0:
        return "Leap year"
    else:
        return "Not a leap year"
    
y = int(input("Enter year to check: "))
print(y,"is",check_year(y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       4     else:
#       5         return "Not a leap year"
# ----> 7 y = int(input("Enter year to check: "))
#       8 print(y,"is",check_year(y))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Lambda
add = lambda a, b: a + b
print(add(5,3))
# Out:
# 8

# %%
# even odd example using lambda

even_odd = lambda n: "even" if n % 2 == 0 else "odd"
print(even_odd(10))
print(even_odd(7))
# Out:
# even
# odd

# %%
square = lambda x: x**2
print(square(4))
# Out:
# 16

# %% [markdown]
# LIBRARIES:
# A library is a collection of pre-written code you can use to do common tasks instead of writing everything from scratch.
#
#  - Saves time
#  - Reduces errors
#  - Adds powerful functionality
#
# Python has built-in libraries and also external libraries you can install with pip.
#
#
# Built-in libraries:
# 1. math-mathematical functions
#    - used to perfon math operations
#
# 2. random-Random numbers
#   - to genearte random numbers
#
# 3. datetime - Date and Time
#   - current date and time
#
# - there are so many libraries in python we can install them using pip
#
# like
# -  numpy : numerical computing(array, amth)
#
# - pandas : data analysis and tables
# - matplolib : data visualization
# - requets : access web APIs
