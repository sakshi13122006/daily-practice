# %%
import tkinter as tk

window = tk.Tk()
window.mainloop()

# %%
import tkinter as tk

window = tk.Tk()
window.title("My first app")
window.geometry("300x200")

window.mainloop()

# %%
import tkinter as tk
window = tk.Tk()
window.title("My app")
window.geometry("300x200")

label = tk.Label(window, text="Hello Sakshi")
label.pack()

window.mainloop()
