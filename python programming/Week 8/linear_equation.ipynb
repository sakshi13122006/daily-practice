# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5,0.25)
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = 6.5 * x + 10.34    #linear eq
y
# Out:
# array([-22.16 , -20.535, -18.91 , -17.285, -15.66 , -14.035, -12.41 ,
#        -10.785,  -9.16 ,  -7.535,  -5.91 ,  -4.285,  -2.66 ,  -1.035,
#          0.59 ,   2.215,   3.84 ,   5.465,   7.09 ,   8.715,  10.34 ,
#         11.965,  13.59 ,  15.215,  16.84 ,  18.465,  20.09 ,  21.715,
#         23.34 ,  24.965,  26.59 ,  28.215,  29.84 ,  31.465,  33.09 ,
#         34.715,  36.34 ,  37.965,  39.59 ,  41.215])

# %%
plt.plot(x, y)
