# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars.csv")
df
# Out:
#     EngineSize  Mileage  Age  Horsepower  FuelType    Price
# 0          1.0    70000    6          70         0   320000
# 1          1.2    60000    5          82         0   380000
# 2          1.5    50000    4         100         1   520000
# 3          1.3    55000    5          90         1   450000
# 4          1.8    40000    3         120         1   680000
# 5          2.0    30000    2         140         1   850000
# 6          1.6    45000    4         110         0   600000
# 7          1.4    52000    5          95         0   480000
# 8          1.2    65000    6          85         0   360000
# 9          2.2    25000    2         160         1   980000
# 10         1.7    38000    3         125         1   720000
# 11         1.1    72000    7          75         0   300000
# 12         1.5    48000    4         105         0   560000
# 13         1.8    42000    3         130         1   760000
# 14         2.0    35000    3         150         1   900000
# 15         1.3    58000    5          92         0   430000
# 16         1.6    47000    4         115         1   630000
# 17         1.9    33000    2         145         1   880000
# 18         1.4    54000    5          98         0   470000
# 19         2.3    20000    1         170         1  1100000

# %%
df.shape
# Out:
# (20, 6)

# %%
df.columns
# Out:
# Index(['EngineSize', 'Mileage', 'Age', 'Horsepower', 'FuelType', 'Price'], dtype='object')

# %%
df.isnull().sum()
# Out:
# EngineSize    0
# Mileage       0
# Age           0
# Horsepower    0
# FuelType      0
# Price         0
# dtype: int64

# %%
# taking any 3 suitable features and building the regression model

# %%
x = df[['Mileage', 'Horsepower', 'Price']]
y = df['Age']
x
# Out:
#     Mileage  Horsepower    Price
# 0     70000          70   320000
# 1     60000          82   380000
# 2     50000         100   520000
# 3     55000          90   450000
# 4     40000         120   680000
# 5     30000         140   850000
# 6     45000         110   600000
# 7     52000          95   480000
# 8     65000          85   360000
# 9     25000         160   980000
# 10    38000         125   720000
# 11    72000          75   300000
# 12    48000         105   560000
# 13    42000         130   760000
# 14    35000         150   900000
# 15    58000          92   430000
# 16    47000         115   630000
# 17    33000         145   880000
# 18    54000          98   470000
# 19    20000         170  1100000

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.score(x, y)
# Out:
# 0.9729419481400728

# %%
plt.scatter(x['Mileage'], y)

# %%
# FEATURE SELECTION

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %%
fs = SequentialFeatureSelector(LinearRegression(), direction = 'backward')

# %%
x = df.drop('Age', axis = 1)

# %%
fs.fit(x, y)
# Out:
# SequentialFeatureSelector(direction='backward', estimator=LinearRegression())

# %%
fs.get_support()
# Out:
# array([False,  True,  True, False,  True])

# %%
x
# Out:
#     Mileage  Horsepower    Price
# 0     70000          70   320000
# 1     60000          82   380000
# 2     50000         100   520000
# 3     55000          90   450000
# 4     40000         120   680000
# 5     30000         140   850000
# 6     45000         110   600000
# 7     52000          95   480000
# 8     65000          85   360000
# 9     25000         160   980000
# 10    38000         125   720000
# 11    72000          75   300000
# 12    48000         105   560000
# 13    42000         130   760000
# 14    35000         150   900000
# 15    58000          92   430000
# 16    47000         115   630000
# 17    33000         145   880000
# 18    54000          98   470000
# 19    20000         170  1100000

# %%
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
lr.score(x , y)
# Out:
# 0.9729419481400728

# %%
Mileage = 4
Horsepower = 220
price = 100000

# %%
newdf = pd.DataFrame({
    'Mileage': [Mileage],
    'Horsepower': [Horsepower],
    'Price': [price]
})

# %%
import warnings
warnings.filterwarnings('ignore')
newdf
# Out:
#    Mileage  Horsepower   Price
# 0        4         220  100000

# %%
lr.predict(newdf)
# Out:
# array([10.93493568])
