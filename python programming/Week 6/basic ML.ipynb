# %% [markdown]
# What is Machine Learning?
#
# Machine Learning (ML) is a branch of Google’s field of Artificial Intelligence that enables computers to learn patterns from data and make decisions or predictions without being explicitly programmed.
#
# 👉 Instead of writing rules manually, the system learns automatically from examples.
#
# Example:
#
# Email spam filter
#
# YouTube recommendations
#
# Face recognition
#
# Voice assistants
#
# 🔹 Why Machine Learning?
#
# Traditional Programming:
#
# Input + Rules → Output
#
#
# Machine Learning:
#
# Input + Output → Model learns Rules
#
#
# ML is useful when:
# ✔ Rules are complex
# ✔ Data is huge
# ✔ Patterns are unknown
#
# 🔹 Types of Machine Learning
# 1️⃣ Supervised Learning
#
# 👉 Model learns using labeled data
#
# Input + Correct Output given
#
# Used for prediction
#
# Tasks:
#
# Classification
#
# Regression
#
# Examples:
#
# House price prediction
#
# Spam detection
#
# Algorithms:
#
# Linear Regression
#
# Logistic Regression
#
# KNN
#
# Decision Tree
#
# 2️⃣ Unsupervised Learning
#
# 👉 Model learns using unlabeled data
#
# No correct answers provided
#
# Finds hidden patterns
#
# Tasks:
#
# Clustering
#
# Association
#
# Examples:
#
# Customer segmentation
#
# Market basket analysis
#
# Algorithms:
#
# K-Means
#
# Hierarchical Clustering
#
# Apriori
#
# 3️⃣ Reinforcement Learning
#
# 👉 Model learns by trial and error with rewards
#
# Agent interacts with environment
#
# Gets reward/penalty
#
# Examples:
#
# Self-driving cars
#
# Game AI
#
# Robotics
#
# 🔹 Basic Terminologies
# Dataset
#
# Collection of data used to train model
#
# Features
#
# Input variables (X)
#
# Target/Label
#
# Output variable (Y)
#
# Model
#
# Mathematical function that predicts output
#
# Training
#
# Teaching model using data
#
# Testing
#
# Checking model performance
#
# Accuracy
#
# How correct predictions are
#
# 🔹 Machine Learning Workflow
# Step 1: Collect Data
#
# CSV, database, sensors
#
# Step 2: Data Preprocessing
#
# Remove missing values
#
# Normalize data
#
# Encoding
#
# Step 3: Split Data
#
# Train (80%)
#
# Test (20%)
#
# Step 4: Choose Algorithm
#
# Example:
#
# Regression → Linear Regression
#
# Classification → Logistic Regression
#
# Step 5: Train Model
# Step 6: Evaluate Model
#
# Metrics:
#
# Accuracy
#
# Precision
#
# Recall
#
# MAE
#
# MSE
#
# Step 7: Deployment
#
# Use model in real apps
#
# 🔹 Popular ML Libraries
# Python Libraries:
# 🟢 Scikit-learn
#
# Easy for beginners
#
# Basic ML algorithms
#
# 🟢 TensorFlow
#
# Deep learning
#
# Developed by Google
#
# 🟢 PyTorch
#
# Flexible
#
# Popular in research
#
# Developed by Meta
#
# 🔹 Applications of ML
#
# ✔ Healthcare – Disease prediction
# ✔ Banking – Fraud detection
# ✔ E-commerce – Recommendations
# ✔ Social Media – Face detection
# ✔ Education – Smart learning systems
#
# 🔹 Advantages
#
# ✅ Automation
# ✅ High accuracy
# ✅ Handles big data
# ✅ Learns continuously
#
# 🔹 Limitations
#
# ❌ Needs large data
# ❌ Expensive training
# ❌ Overfitting risk
# ❌ Hard to interpret sometimes
#
# 🔹 Simple Example (Concept)
# Problem:
#
# Predict house price
#
# Inputs:
#
# Area
#
# Bedrooms
#
# Location
#
# Output:
#
# Price
#
# Model learns:
#
# Price = f(area, bedrooms, location)
